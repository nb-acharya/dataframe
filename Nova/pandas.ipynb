# %%
import pandas as pd
df= pd.read_csv('./dataset/Amazon Sale Report.csv',low_memory=False)

# %%
df.shape
# Out:
# (128975, 24)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   Order ID            128975 non-null  str
#  2   Date                128975 non-null  str
#  3   Status              128975 non-null  str
#  4   Fulfilment          128975 non-null  str
#  5   Sales Channel       128975 non-null  str
#  6   ship-service-level  128975 non-null  str
#  7   Style               128975 non-null  str
#  8   SKU                 128975 non-null  str
#  9   Category            128975 non-null  str
#  10  Size                128975 non-null  str
#  11  ASIN                128975 non-null  str
#  12  Courier Status      122103 non-null  str
#  13  Qty                 128975 non-null  int64
#  14  currency            121180 non-null  str
#  15  Amount              121180 non-null  float64
# ...

# %%
df.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category  ... currency  Amount    ship-city   ship-state  \
# ...

# %%
df[:5]  # similar to df.head(5)
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category  ... currency  Amount    ship-city   ship-state  \
# ...

# %%
type(df['Date'])
# Out:
# pandas.Series

# %%
type(df)
df["Date"].shape
# Out:
# (128975,)

# %%
df[['Date','Status']].shape
# Out:
# (128975, 2)

# %%
df2 = pd.DataFrame(
    {
        "Name": [
            "Braund", "Niroj","Alex"
        ],
        "Age": [22,34,55],
            "Sex": ["male","male","female"]
    }
)

# %%
df2["Sex"]
# Out:
# 0      male
# 1      male
# 2    female
# Name: Sex, dtype: str

# %%
grade = pd.Series([22,23,265], name="Grade")

# %%
grade
# Out:
# 0     22
# 1     23
# 2    265
# Name: Grade, dtype: int64

# %% [markdown]
# ### syntax
# ```df.describe()```

# %%
# pd.read.csv("data/titanic.csv")
# df.head()

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   Order ID            128975 non-null  str
#  2   Date                128975 non-null  str
#  3   Status              128975 non-null  str
#  4   Fulfilment          128975 non-null  str
#  5   Sales Channel       128975 non-null  str
#  6   ship-service-level  128975 non-null  str
#  7   Style               128975 non-null  str
#  8   SKU                 128975 non-null  str
#  9   Category            128975 non-null  str
#  10  Size                128975 non-null  str
#  11  ASIN                128975 non-null  str
#  12  Courier Status      122103 non-null  str
#  13  Qty                 128975 non-null  int64
#  14  currency            121180 non-null  str
#  15  Amount              121180 non-null  float64
# ...

# %%
df['Qty'].unique()
# Out:
# array([ 0,  1,  2, 15,  3,  9, 13,  5,  4,  8])

# %%
above3=df[df['Qty'] > 3]
above3.head()
# Out:
#        index             Order ID      Date                        Status  \
# 937      937  S02-5278980-4327051  04-30-22                       Shipped
# 3631    3631  S02-1006261-5356758  04-28-22                       Shipped
# 3636    3636  S02-6828927-1180856  04-28-22                       Shipped
# 11160  11160  403-4106553-1691525  04-23-22  Shipped - Delivered to Buyer
# 17338  17338  403-2332292-9207530  04-20-22  Shipped - Delivered to Buyer
#
#       Fulfilment Sales Channel  ship-service-level    Style  \
# 937       Amazon     Non-Amazon           Standard    BL017
# 3631      Amazon     Non-Amazon           Standard  JNE2305
# 3636      Amazon     Non-Amazon           Standard  JNE2305
# 11160   Merchant      Amazon.in           Standard    J0013
# 17338   Merchant      Amazon.in           Standard  JNE2265
#
#                       SKU Category  ... currency  Amount  ship-city  \
# 937         BL017-63BLACK   Blouse  ...      NaN     NaN      Surat
# ...

# %%
"""
we can use all kinds of expression >, <, <=, >=, !=, &, |
loc
iloc
boolean indexing 
isin function
"""

# %% [markdown]
# ### Data Filter
#
# operations: | or, & and, ~ not
#
# **Boolean Indexing:** is a data filtering technique that uses an array of True and False values (a mask) to select the specific elements from the data structures like.
